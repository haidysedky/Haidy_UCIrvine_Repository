# %%
import requests
import json
from config import api_key

# %%
base_url = 'https://openapi.etsy.com/v2/listings/active?api_key='

# %%
url = base_url + api_key

# %%
response = requests.get(url).json()

# %%
response["results"]
# Out:
# [{'listing_id': 540504237,
#   'state': 'active',
#   'user_id': 14986070,
#   'category_id': 69150455,
#   'title': 'Beautifully Wild Unicorn Tote Bag - Canvas Bag - GLITTER!',
#   'description': 'you won&#39;t believe the sparkle and shine on this bag - its mesmerizing!\n\nThis bag measures 13.5&quot; wide 13.5&quot; deep and 3.5&quot; wide. It is made of durable canvas and is completely washable! (I recommend washing inside out and drying on low heat, or hang to dry)\n\nThere is plenty of room to store all of your things for work, school, the gym, the beach, the barn, take this bag everywhere!\n\nThis bag makes a great gift, and is totally customizable! choose your bag color and design color in the drop down boxes\n\nCustom orders are always welcome, please send me a message to discuss your ideas!',
#   'creation_tsz': 1538170652,
#   'ending_tsz': 1548715052,
#   'original_creation_tsz': 1499138435,
#   'last_modified_tsz': 1538170652,
#   'price': '17.99',
#   'currency_code': 'USD',
#   'quantity': 7,
#   'sku': [],
#   'tags': ['purse',
#    'horse',
#    'equestrian',
#    'lularoe',
#    'pony',
#    'bag',
#    'reusable bag',
#    'grocery bag',
#    'gift',
#    'backpack',
#    'girl',
#    'sparkle',
#    'bling'],
#   'category_path': ['Bags and Purses'],
#   'category_path_ids': [69150455],
#   'materials': ['Canvas', 'Vinyl'],
#   'shop_section_id': None,
#   'featured_rank': None,
#   'state_tsz': 1516204223,
#   'url': 'https://www.etsy.com/listing/540504237/beautifully-wild-unicorn-tote-bag-canvas?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 113,
#   'num_favorers': 10,
#   'shipping_template_id': None,
#   'processing_min': 5,
#   'processing_max': 10,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '5',
#   'item_weight_unit': 'oz',
#   'item_length': '7',
#   'item_width': '7',
#   'item_height': '3',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 190,
#   'taxonomy_path': ['Bags & Purses', 'Totes'],
#   'used_manufacturer': False},
#  {'listing_id': 468955404,
#   'state': 'active',
#   'user_id': 60106751,
#   'category_id': 68910162,
#   'title': 'Happy Halloween Title',
#   'description': 'For this listing you will receive a &quot;Happy Halloween&quot; title. They measure 3.15 inches in height and 5.10 inches wide. The colors shown are black, orange and green.\n\nMade from Acid and Lignin free cardstock\n\nIf you would like different colors, different size or additional quantities please convo me and I will be happy to work with you as best as I can.\n\nThese are perfect for scrapbooking, Halloween projects, Halloween parties, the ideas are endless',
#   'creation_tsz': 1538170650,
#   'ending_tsz': 1548715050,
#   'original_creation_tsz': 1475285642,
#   'last_modified_tsz': 1538170650,
#   'price': '1.75',
#   'currency_code': 'USD',
#   'quantity': 6,
#   'sku': [],
#   'tags': ['Happy Halloween',
#    'Halloween die cuts',
#    'Halloween party',
#    'Halloween scrapbook',
#    'scrapbooking',
#    'die cuts',
#    'cricut die cut',
#    'Halloween title',
#    'scrapbook die cuts'],
#   'category_path': ['Supplies', 'Scrapbooking', 'Die Cut'],
#   'category_path_ids': [69150433, 68887752, 68910162],
#   'materials': [],
#   'shop_section_id': 17756022,
#   'featured_rank': None,
#   'state_tsz': 1512942014,
#   'url': 'https://www.etsy.com/listing/468955404/happy-halloween-title?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 29,
#   'num_favorers': 2,
#   'shipping_template_id': 21255726692,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 6594,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Canvas & Surfaces',
#    'Paper',
#    'Die Cuts'],
#   'used_manufacturer': False},
#  {'listing_id': 201960056,
#   'state': 'active',
#   'user_id': 21993190,
#   'category_id': 68933588,
#   'title': 'Godzilla Universe T-Shirts',
#   'description': 'Glow in the Dark Silkscreened ink on this GILDAN brand shirt.  Available in men&#39;s M, L, XL, XXL. Small number of each.',
#   'creation_tsz': 1538170650,
#   'ending_tsz': 1548715050,
#   'original_creation_tsz': 1409602063,
#   'last_modified_tsz': 1538170650,
#   'price': '25.00',
#   'currency_code': 'USD',
#   'quantity': 18,
#   'sku': [],
#   'tags': ['Godzilla',
#    'Science Fiction',
#    'Mothra',
#    'Rodan',
#    'Godjira',
#    'Kaiju',
#    'T-shirt',
#    'Ghidora',
#    'Angurus',
#    'Radioactive',
#    'Mecha Godzilla',
#    'Monster Island',
#    'TOHO Terrors'],
#   'category_path': ['Clothing', 'Men', 'Shirt'],
#   'category_path_ids': [69150353, 69153053, 68933588],
#   'materials': ['Cotton'],
#   'shop_section_id': 11902913,
#   'featured_rank': None,
#   'state_tsz': 1449091319,
#   'url': 'https://www.etsy.com/listing/201960056/godzilla-universe-t-shirts?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 586,
#   'num_favorers': 80,
#   'shipping_template_id': None,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'collective',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': '32',
#   'item_weight_unit': 'oz',
#   'item_length': '12',
#   'item_width': '9',
#   'item_height': '4',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': 'men',
#   'occasion': None,
#   'style': ['Sci Fi', 'Fantasy'],
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 444,
#   'taxonomy_path': ['Clothing', "Men's Clothing", 'Shirts & Tees'],
#   'used_manufacturer': False},
#  {'listing_id': 451237808,
#   'state': 'active',
#   'user_id': 60106751,
#   'category_id': 69150433,
#   'title': 'Football Player Silhouette Die Cut Set of 3',
#   'description': 'Football season is coming up and these die cuts are perfect to add to your parties, scrapbook pages, or any projects!\n\n You will receive a set of 3 Football Player Silhouette. Each one measures  3 inches in height. The colors shown is black. \n\nMade from Acid and Lignin cardstock.\n\nIf you would like different sizes, colors or larger quantities please convo me and I will be happy to work with you.\n\nThese are perfect for birthdays, scrapbook pages, cards, football season parties, tags, the ideas are endless.',
#   'creation_tsz': 1538170648,
#   'ending_tsz': 1548715048,
#   'original_creation_tsz': 1467918805,
#   'last_modified_tsz': 1538170648,
#   'price': '1.50',
#   'currency_code': 'USD',
#   'quantity': 9,
#   'sku': [],
#   'tags': ['cricut',
#    'cricut die cut',
#    'football die cut',
#    'sport die cut',
#    'football player',
#    'football party',
#    'scrapbook die cut',
#    'paper goods',
#    'sports party',
#    'scrapbooking',
#    'football sillhoutte'],
#   'category_path': ['Supplies'],
#   'category_path_ids': [69150433],
#   'materials': [],
#   'shop_section_id': 19458151,
#   'featured_rank': None,
#   'state_tsz': 1517885040,
#   'url': 'https://www.etsy.com/listing/451237808/football-player-silhouette-die-cut-set?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 91,
#   'num_favorers': 9,
#   'shipping_template_id': None,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': True,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 6594,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Canvas & Surfaces',
#    'Paper',
#    'Die Cuts'],
#   'used_manufacturer': False},
#  {'listing_id': 633420182,
#   'state': 'active',
#   'user_id': 70429642,
#   'category_id': 69151567,
#   'title': 'Bola de grossesse cage papillon coeur noir noeud blanc satiné et son attrape rêves avec ses perles Swarovski',
#   'description': 'Je vends ce bola de grossesse cage papillon coeur noir noeud blanc satiné et son attrape rêves avec ses perles Swarovski créé dans mon monde de Douceurs Perlées\n\nPrix 24.50 euros\n\nChaine de 105 cm et rallonge de 5 cm\n\nLes frais de livraison sont offerts et envoi en écrin cadeau et courrier suivi sous 5 jours ouvrés hors personnalisation',
#   'creation_tsz': 1538170647,
#   'ending_tsz': 1548715047,
#   'original_creation_tsz': 1538170647,
#   'last_modified_tsz': 1538170648,
#   'price': '24.50',
#   'currency_code': 'EUR',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['naissance',
#    'baby shower',
#    'attrape rêves',
#    'plume',
#    'papillon',
#    'cœur',
#    'noeud',
#    'strass',
#    'grossesse',
#    'maman',
#    'bola de grossesse',
#    'future maman',
#    'bébé'],
#   'category_path': ['Jewelry', 'Necklace'],
#   'category_path_ids': [68887482, 69151567],
#   'materials': [],
#   'shop_section_id': None,
#   'featured_rank': None,
#   'state_tsz': 1538170647,
#   'url': 'https://www.etsy.com/listing/633420182/bola-de-grossesse-cage-papillon-coeur?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 0,
#   'num_favorers': 0,
#   'shipping_template_id': 45478573082,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': None,
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': None,
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': True,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'fr',
#   'has_variations': False,
#   'taxonomy_id': 1222,
#   'taxonomy_path': ['Jewelry', 'Necklaces', 'Charm Necklaces'],
#   'used_manufacturer': False},
#  {'listing_id': 617913376,
#   'state': 'active',
#   'user_id': 147353482,
#   'category_id': 68892264,
#   'title': 'Open Bar Sign, Wedding Bar Sign, Wedding Decorations, Bridal Shower Decorations, Wedding Sign,  Bubbly Bar, Wedding Drink Sign, Printable',
#   'description': 'Open Bar Wedding Sign, Printable Wedding Drink Sign\n\nKeep your guests partying all night long with this fun DIY Wedding Sign\n\nWant a rustic look? Print on heavy Kraft paper, available at any craft supply store! \n\n***This is a PDF Digital File Download. A link to download the file will be available after purchase. No physical item will be posted to you***\n\n\n2 FINISHED SIZES: 5x7 inch and 8x10 inch\n\nPrint off as many as you need. \n\n.......................................................................................................\nWHAT IS INCLUDED:\n\n1 - 5x7 PDF Wedding Sign\n1 - 8x10 PDF Wedding Sign\n\n.......................................................................................................\nREADY TO BUY? HOW DO I GET MY FILES:  \n\n1. Download the PDF file(s)\n2. Open with Adobe Reader \n— Free download at: www.get.adobe.com/reader\n3. Update editable text fields and save (Your names, wedding date, etc.)\n— To edit text style, color, size, etc. type Command-E on Mac or Ctrl-E on PC to open type tools. (Applies only to editable templates)\n4. Print at home or your local copy shop.\n5. Cut along indicated trim marks\n\n.......................................................................................................\nDELIVERY:\n\nYou will receive your files as an INSTANT DOWNLOAD after checkout. Once payment is confirmed, you will receive notice with your download link to your Etsy e-mail.\n\n.......................................................................................................\n\nIMPORTANT INFO – READ BEFORE PURCHASING \n\n• You must use ADOBE ACROBAT READER (free download) to edit the templates.\n• Colors may vary depending on your monitor, color settings, printer and paper stock.\n• To edit text style, color, size, etc. type Command-E on Mac or Ctrl-E on PC to open type tools. (Applies only to editable templates)\n• Not all text is editable. Text that is a part of the design cannot be changed. Please see all images in gallery to see which text is editable.\n• Template size and design layout cannot be changed.\n• Due to the digital nature of our products, returns or refunds are not possible. Please ask any questions before purchasing.\n\n.......................................................................................................\nTERMS OF USE\n\nBy purchasing one of our products you are agreeing to the following terms of use:\n\n- This file is for personal use only (not commercial use/resale). You may not forward, share, sell or distribute the file. It is for non-commercial use only. All rights are reserved ©The Golden Paperie\n\n- Due to the digital nature of our products we are unable to provide a refund for your purchase, please read all listing descriptions carefully. If you have any questions do not hesitate to ask. \n\n- Colors may change slightly from what you see on your screen to when it is printer. This may be caused by the following factors: your screen resolution, quality of your printer, quality of the inks you have used and more. We do not issue a refund due to color variations. \n\n- By purchasing this product you are confirming you have read, understood and agreed to the product description and shop policies stated.\n.......................................................................................................\n\nFor more printables visit: TheGoldenPaperie.Etsy.Com',
#   'creation_tsz': 1538170647,
#   'ending_tsz': 1548715047,
#   'original_creation_tsz': 1532652825,
#   'last_modified_tsz': 1538170647,
#   'price': '5.89',
#   'currency_code': 'CAD',
#   'quantity': 977,
#   'sku': [],
#   'tags': ['wedding bar sign',
#    'wedding sign pdf',
#    'printable sign',
#    'open bar sign',
#    'open bar menu',
#    'diy bar sign',
#    'wedding drink sign',
#    'reception decor',
#    'bubbly bar',
#    'engagement party',
#    'printable decor',
#    'wedding templates',
#    'wedding decorations'],
#   'category_path': ['Weddings', 'Decoration'],
#   'category_path_ids': [68887494, 68892264],
#   'materials': ['PDF'],
#   'shop_section_id': 23738891,
#   'featured_rank': None,
#   'state_tsz': 1535133307,
#   'url': 'https://www.etsy.com/listing/617913376/open-bar-sign-wedding-bar-sign-wedding?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 718,
#   'num_favorers': 99,
#   'shipping_template_id': None,
#   'processing_min': None,
#   'processing_max': None,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': True,
#   'file_data': '2 PDF',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 6121,
#   'taxonomy_path': ['Weddings', 'Decorations', 'Signs'],
#   'used_manufacturer': False},
#  {'listing_id': 611294911,
#   'state': 'active',
#   'user_id': 22493219,
#   'category_id': 68887434,
#   'title': 'Skull Dog Collar, Cool Dog Collars for Male or Female Dog, Can be Personalized',
#   'description': 'An eye-catching skull and butterfly, illustrated by Artist Jillian Irvine, make this the ultimate cool dog collar for a male or female dog. Our Skull Dog Collar is available in 1 inch or 1 1/2 inch widths.\n\nChoose from a standard black buckle, a reflective buckle, or an aluminum side-release buckle that can be personalized with engraving. Constructed of high quality black nylon webbing for structure and durability, this dog collar features a molded (not welded) D ring. The aluminum slide allows you to adjust the collar for a perfect custom fit. Be happy knowing that a portion of every purchase is donated to animal rescue organizations.\n\nThis dog collar arrives in a charming gift box that&#39;s ready to give. \n\nPlease choose your dog&#39;s collar size and color you are ordering at checkout. Be sure to leave 2 fingers of extra room when measuring around your dog&#39;s neck:\n\nSmall (1” width) fits 9” - 13” neck\nMedium (1” or 1 1/2&quot; widths) fits 11” - 17” neck\nLarge (1” or 1 1/2&quot; widths) fits 15” - 24” neck\nX-Large (1” or 1 1/2&quot; widths) fits 18&quot; - 27&quot; neck\n\nEngraving\nUpon checkout, please specify font and up to 3 lines of text, up to 15 characters per line.\n\nCare Instructions\nHand wash in cold water with mild detergent and lay flat to dry.\n\nYou may also like:\n\nAdd a matching leash:\nhttps://etsy.me/2n1Xawx\n\nVisit our shop:\nhttps://www.etsy.com/shop/youhadmeatwoof\n\nView our dog collars in 1 1/2&quot; widths:\nhttps://etsy.me/2LH58d8\n\nView our dog collars in 1&quot; widths:\nhttps://etsy.me/2IHi3u2\n\nView our dog collars in 3/4&quot; and 5/8&quot; widths:\nhttps://etsy.me/2kndrdW',
#   'creation_tsz': 1538170647,
#   'ending_tsz': 1548715047,
#   'original_creation_tsz': 1525132164,
#   'last_modified_tsz': 1538170647,
#   'price': '19.00',
#   'currency_code': 'USD',
#   'quantity': 4,
#   'sku': [],
#   'tags': ['skull dog collar',
#    'skulls',
#    'cool dog collars',
#    'for male',
#    'for female',
#    'male dog collar',
#    'female dog collar',
#    'personalized',
#    'dog collar',
#    'butterfly dog collar',
#    'butterfly',
#    'black',
#    'nylon webbing'],
#   'category_path': ['Pets'],
#   'category_path_ids': [68887434],
#   'materials': ['nylon webbing'],
#   'shop_section_id': 12300311,
#   'featured_rank': None,
#   'state_tsz': 1529018145,
#   'url': 'https://www.etsy.com/listing/611294911/skull-dog-collar-cool-dog-collars-for?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 17,
#   'num_favorers': 2,
#   'shipping_template_id': 48356840685,
#   'processing_min': 5,
#   'processing_max': 7,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '5',
#   'item_weight_unit': 'oz',
#   'item_length': '8',
#   'item_width': '3',
#   'item_height': '2',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1384,
#   'taxonomy_path': ['Pet Supplies',
#    'Pet Collars & Leashes',
#    'Pet Collars & Jewelry'],
#   'used_manufacturer': False},
#  {'listing_id': 280630696,
#   'state': 'active',
#   'user_id': 23894037,
#   'category_id': 69188171,
#   'title': 'iPad Case . iPad Pro 10.5 . Black Stripes with Rose Gold Smart Cover Hard Case . Kate Spade Inspired',
#   'description': 'New!! Finish Options - Give your Macbook, iPad, iPhone and Microsoft Surface a unique and distinctive look.\n\nReference to  Menu options (last letters on each selection)\nG = Glossy / Shiny\nM = Matte / Non Shiny\nB = Brushed Texture\nSP = Glossy Sparkle Shimmer\nS = Satin \n\nMore Details:\n. https://www.clique.boutique/post/88033924638/glossy-vs-matte-video .\n\n------------------------ \n\nLive, Love & Sparkle, add a beautiful and unique keycal\n. https://etsy.me/2NbFt9C .\n\nThis is a Hybrid Smart Hard Case!, it&#39;s made using a Rose Gold Smart Cover Hard Case with our Pro-vinyl design professionally installed over the case.\n\n&gt;&gt;&gt;  Matte or Glossy &lt;&lt;&lt;\nWhat is Matte? Matte finish is a non-glossy, satin-type finish. It allows fingerprints and smudges to fade into the surface of the skin and gives a unique look and feel to the artwork.\n\nWhat is Glossy? Glossy finish has a shiny, glossy, appearance and the colors within the artwork may seem to be more vibrant.\n\n&gt;&gt;&gt;  Makers Gonna Make! &lt;&lt;&lt;\nFinest Craftsmanship in Vinyl Skins, custom made in just 8 Days.\n- All of our skins are hand made just for you with care and love, we require * 8 days to create and ship each skin with absolute excellence, we are sure the wait will be worthwhile.\n- Ships to U.S. & WorldWide \n\n&gt;&gt;&gt; HANDMADE IN USA &lt;&lt;&lt;\nAll of our products are made shortly after your order is placed. All of our materials are sourced from local suppliers, right here in the USA.\n\n&gt;&gt;&gt; We are here to make you Happy!! &lt;&lt;&lt;\nYou will Love our Product, it&#39;s guaranteed.\nIf you are not completely happy with your purchase -- for any reason and would like to exchange it for another design, please send us a convo and we&#39;ll find a way to fix it.\n\n&gt;&gt;&gt; Returns &lt;&lt;&lt;\nSince products from Clique are made to order, products cannot be returned for refund. If you are not satisfied by defects on the products (such as scratched cases or printing errors), please contact us for assistance and our team will review the problem and arrange an exchange of the product with a new one if necessary.\n\n&gt;&gt;&gt; Follow us on Instagram &lt;&lt;&lt;\nWe hope you like and enjoy our product. Please remember to follow us in Instagram @cliqueshops to stay updated with new designs you will love.',
#   'creation_tsz': 1538170646,
#   'ending_tsz': 1548715046,
#   'original_creation_tsz': 1463491814,
#   'last_modified_tsz': 1538170646,
#   'price': '59.99',
#   'currency_code': 'USD',
#   'quantity': 61,
#   'sku': [],
#   'tags': ['iPad Case',
#    'iPad Pro 10',
#    'minimal',
#    'minimalist',
#    'mothers day gift',
#    'customized',
#    'monogram',
#    'simple',
#    'rose gold',
#    'iPad Pro case',
#    'kate spade'],
#   'category_path': ['Accessories', 'Case', 'Cell Phone'],
#   'category_path_ids': [69150467, 68892196, 69188171],
#   'materials': ['laminated premium automotive grade cast vinyl',
#    'special adhesive backing leaves no residue'],
#   'shop_section_id': 14270241,
#   'featured_rank': None,
#   'state_tsz': 1500410856,
#   'url': 'https://www.etsy.com/listing/280630696/ipad-case-ipad-pro-105-black-stripes?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 3761,
#   'num_favorers': 168,
#   'shipping_template_id': 1684093579,
#   'processing_min': 8,
#   'processing_max': 8,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': 'women',
#   'occasion': None,
#   'style': ['Art Deco', 'Modern'],
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 874,
#   'taxonomy_path': ['Electronics & Accessories',
#    'Electronics Cases',
#    'Tablet & Reader Cases'],
#   'used_manufacturer': False},
#  {'listing_id': 637562251,
#   'state': 'active',
#   'user_id': 148588614,
#   'category_id': 68933546,
#   'title': 'Baby Halloween Halloween Costume Baby Costume Halloween Outfit Tutu Baby Girl Halloween Halloween bodysuit baby gift Cake smash photo prop',
#   'description': 'An adorable outfit for your little one&#39;s Halloween. The romper is soft 100% cotton with glitter and flat color vinyl. This outfit would be great for Halloween, birthday parties, cake smash, and many fun occasions.\n\nBodysuit comes in: 6 months, 12 months and 18 months and can be long or short sleeve. If you want short sleeve indicate in a message to the shop please.\n                                  \n***Please wash the bodysuit inside out, gentle cycle and lay flat to dry.\n\nThe full orange tutu is 2 layers deep with a satin bow, The waist is expandable.\nWash tutu gentle cycle and lay flat to dry.\n\nTutu is available in sizes:   9M to 18M - 8.5 inches across.  Length is approx. 9 inches.  \n                                                    12M to 24M - 9 inches across.  Length is approx 9.5 inches.\n\nThe headband is made with orange, white and black ribbon decorated with a plastic spider.\n\n\nHandling time is 1-3 days. I am responsible for your purchase until it reaches the Post Office, after that it is out of my control. I will carefully inspect that the item is in perfect condition before I will ship. I am not responsible for delays due to mis-delivery or the wrong address. Thank you for your understanding.\n\n- Some items contain small parts that can be a potential hazard for children.\n- Never leave children unsupervised.\n- Buyer resumes all responsibility.\n\n*** Please read all shop policies ***\n\nThank you for shopping with MissMunckinCouture. If you have any questions contact me and I will respond as soon as possible.',
#   'creation_tsz': 1538170644,
#   'ending_tsz': 1548715044,
#   'original_creation_tsz': 1534709490,
#   'last_modified_tsz': 1538170644,
#   'price': '5.95',
#   'currency_code': 'USD',
#   'quantity': 10,
#   'sku': [],
#   'tags': ['Baby Halloween',
#    'Halloween Costume',
#    'Halloween Outfit',
#    'Halloween Bodysuit',
#    'Halloween',
#    'Cake smash',
#    'Baby Gift',
#    'Tutu',
#    'Baby Costume',
#    'Photo Prop',
#    'Girl Halloween',
#    'Princess Dress',
#    'Baby Headband'],
#   'category_path': ['Clothing', 'Children', 'Baby'],
#   'category_path_ids': [69150353, 68889526, 68933546],
#   'materials': ['Cotton', 'Chiffon'],
#   'shop_section_id': None,
#   'featured_rank': 1,
#   'state_tsz': 1534709490,
#   'url': 'https://www.etsy.com/listing/637562251/baby-halloween-halloween-costume-baby?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 13,
#   'num_favorers': 5,
#   'shipping_template_id': 56723599587,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': '10',
#   'item_weight_unit': 'oz',
#   'item_length': '15',
#   'item_width': '12',
#   'item_height': '4',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 403,
#   'taxonomy_path': ['Clothing', "Girls' Clothing", "Baby Girls' Clothing"],
#   'used_manufacturer': False},
#  {'listing_id': 595532060,
#   'state': 'active',
#   'user_id': 146205926,
#   'category_id': 68925952,
#   'title': 'Print - Meatboy',
#   'description': '&quot;Meatboy&quot;\nOriginal piece created by Betty Hex. (Ink)\n\n8x10&quot; / 11x14&quot; print on high quality archival matte photo paper.\n\nFREE SHIPPING - US only. $10 flat rate worldwide.\n\nSealed in a clear sleeve.',
#   'creation_tsz': 1538170643,
#   'ending_tsz': 1548715043,
#   'original_creation_tsz': 1524394667,
#   'last_modified_tsz': 1538170643,
#   'price': '12.00',
#   'currency_code': 'USD',
#   'quantity': 99,
#   'sku': [],
#   'tags': ['occult',
#    'witchcraft',
#    'art',
#    'macabre',
#    'dark art',
#    'prints',
#    'print',
#    'magic',
#    'witches',
#    'death',
#    'skull',
#    'gore',
#    'bones'],
#   'category_path': ['Art', 'Print', 'Digital'],
#   'category_path_ids': [68887312, 68892154, 68925952],
#   'materials': ['ink'],
#   'shop_section_id': 23796482,
#   'featured_rank': None,
#   'state_tsz': 1524394667,
#   'url': 'https://www.etsy.com/listing/595532060/print-meatboy?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 12,
#   'num_favorers': 0,
#   'shipping_template_id': 55571792290,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': '3',
#   'item_weight_unit': 'oz',
#   'item_length': '12',
#   'item_width': '9',
#   'item_height': '1',
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 2078,
#   'taxonomy_path': ['Art & Collectibles', 'Prints', 'Digital Prints'],
#   'used_manufacturer': False},
#  {'listing_id': 574852604,
#   'state': 'active',
#   'user_id': 15777219,
#   'category_id': 69150433,
#   'title': 'Vintage 1950&#39;s Butterick 5455 Two-Piece Suit Dress Sewing Pattern Size 15 Bust 32',
#   'description': 'The suit-dress is a practical fashion...wonderful for town or travel everywhere! The three-button jacket-blouse has dressmaker details: rounded lapels, smart double-buttoned mock pockets. Five-piece skirt in same or contrast fabric. Sewing pattern is unused and Factory Folded.',
#   'creation_tsz': 1538170642,
#   'ending_tsz': 1548715042,
#   'original_creation_tsz': 1516746861,
#   'last_modified_tsz': 1538170643,
#   'price': '14.50',
#   'currency_code': 'USD',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['Butterick 5455',
#    'vintage patterns',
#    'sewing patterns',
#    '1950s sewing pattern'],
#   'category_path': ['Supplies'],
#   'category_path_ids': [69150433],
#   'materials': [],
#   'shop_section_id': 10977083,
#   'featured_rank': None,
#   'state_tsz': 1538152831,
#   'url': 'https://www.etsy.com/listing/574852604/vintage-1950s-butterick-5455-two-piece?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 20,
#   'num_favorers': 10,
#   'shipping_template_id': 15799760,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'someone_else',
#   'is_supply': 'true',
#   'when_made': '1950s',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 6343,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Patterns & How To',
#    'Patterns & Blueprints'],
#   'used_manufacturer': False},
#  {'listing_id': 568088578,
#   'state': 'active',
#   'user_id': 30777547,
#   'category_id': 69150467,
#   'title': 'Will you be my BEST MAN Gift Personalized Bottle Opener Beer Bottle Cap Catcher Opener Will you be my Groomsman Gift Beer Cap Catcher',
#   'description': 'Hand crafted rustic wood bottle opener and catcher,  A gift for a special person or couple for any event when you need to give something memorable.  Each comes with a rustic opener.  Personalization is designed by our own graphic artist and hand painted on with durable oil-based flat black paint.   Box holds your caps.   Opener is free standing or can have a key hole cut on the back to hang.  Opener measures 12&quot; x 6&quot; x 4&quot;  These wooden cap catchers fabulous gifts for your wedding party or any occasion when you want to give a unique personal gift.  \n\nSpecify how you would like your tote personalized in order comments.  \n\nOur items are made to order and will take 2-4 weeks depending on time of year.  Please look at our current lead time in shop information.  \n\nWe are glad to combine shipping costs on multiples to save you on the total cost of your order.  \n\nVIEW OUR OTHER DESIGNS: https://www.etsy.com/shop/AbsoluteImpressions?ref=pr_shop_more\n\nNote:  There will be variations in the color and the grain of the wood of each different piece.  \n\nPLEASE NOTE: Our totes are made by design to be rustic. We hand select our wood with knots and cracks to add character to each piece and may even use special techniques to make them look even more distressed. If you are looking for highly polished smooth furniture and not rustic, then our product may not be what you&#39;re looking for. Although our wood is carefully constructed, sturdy and sanded, it will not be smooth or free of knots and cracks, etc. This is part of the character and a signature of our design. We take great pride in creating a custom piece for each of our customers like we were making it for our own family, but also understand that the rustic, primitive, repurposed look is not everyone&#39;s liking and want you to be pleased with your specially made piece.\n\nCUSTOM ORDERS WELCOME!  We are happy to create a custom design for you or add additional text to one of our designs.  Depending on the extent of the custom work there may or may not be an extra charge, but we&#39;ll let you know before you place your order.  \n\nWe will send a mock up of your request for personalization as an Etsy message.  If no response within 3 days is no made, approval will be assumed.',
#   'creation_tsz': 1538170642,
#   'ending_tsz': 1548715042,
#   'original_creation_tsz': 1514157597,
#   'last_modified_tsz': 1538170642,
#   'price': '24.95',
#   'currency_code': 'USD',
#   'quantity': 30,
#   'sku': [],
#   'tags': ['Bottle Opener',
#    'Wood',
#    'Personalized',
#    'Gift',
#    'beer bottle opener',
#    'best man gift',
#    'groomsman gift',
#    'beer',
#    'BEER BOTTLE',
#    'PERSONALIZED BOTTLE',
#    'will you be',
#    'best man',
#    'will you be my best'],
#   'category_path': ['Accessories'],
#   'category_path_ids': [69150467],
#   'materials': ['Wood', 'Metal', 'Stain', 'Rustic Bottle Opener', 'Paint'],
#   'shop_section_id': None,
#   'featured_rank': None,
#   'state_tsz': 1536550802,
#   'url': 'https://www.etsy.com/listing/568088578/will-you-be-my-best-man-gift?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 2180,
#   'num_favorers': 349,
#   'shipping_template_id': 51785018888,
#   'processing_min': 15,
#   'processing_max': 20,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1,
#   'taxonomy_path': ['Accessories'],
#   'used_manufacturer': False},
#  {'listing_id': 605252890,
#   'state': 'active',
#   'user_id': 40641533,
#   'category_id': 68889876,
#   'title': 'BookFair Gold Archival Unisex Tee - book lover gift - graphic tee - book nerd - soft t-shirt  - logo t-shirt',
#   'description': 'This t-shirt is everything you&#39;ve dreamed of and more. It feels soft and lightweight, with the right amount of stretch. It&#39;s comfortable and flattering for both men and women. \n\n• 100% combed and ring-spun cotton (heather colors contain polyester)\n• Fabric weight: 4.2 oz (142 g/m2)\n• Shoulder-to-shoulder taping\n• Side-seamed',
#   'creation_tsz': 1538170641,
#   'ending_tsz': 1548715041,
#   'original_creation_tsz': 1528227394,
#   'last_modified_tsz': 1538170641,
#   'price': '18.00',
#   'currency_code': 'USD',
#   'quantity': 999,
#   'sku': [],
#   'tags': ['t-shirt',
#    'graphic tee',
#    't shirt',
#    'tshirt',
#    'booklover',
#    'booknerd',
#    'bookworm',
#    'writer',
#    'poet',
#    'novelist',
#    'unique gift'],
#   'category_path': ['Clothing', 'Shirt'],
#   'category_path_ids': [69150353, 68889876],
#   'materials': [],
#   'shop_section_id': 24065457,
#   'featured_rank': None,
#   'state_tsz': 1528227407,
#   'url': 'https://www.etsy.com/listing/605252890/bookfair-gold-archival-unisex-tee-book?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 7,
#   'num_favorers': 0,
#   'shipping_template_id': 46168041771,
#   'processing_min': 7,
#   'processing_max': 8,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 482,
#   'taxonomy_path': ['Clothing',
#    'Unisex Adult Clothing',
#    'Tops & Tees',
#    'T-shirts'],
#   'used_manufacturer': False},
#  {'listing_id': 474686219,
#   'state': 'active',
#   'user_id': 10553830,
#   'category_id': 69150425,
#   'title': 'Large pottery berry bowl in your choice of glaze. Wheel thrown berry bowl with plate / colander / strainer / MADE TO ORDER (6 weeks)',
#   'description': 'This large 9&quot;-10&quot; hand thrown pottery berry bowl strainer is both beautiful and multi-functional. Use it for piece for rinsing and serving berries, draining large diameter pasta, or setting on the counter with fruit. I designed this piece with lots of hand cut holes and a matching plate to catch drips. The trimmed and cut out foot keeps the bowl from suctioning to the plate with the liquid.\n\nMade to order- please allow up to 6 weeks for completion.\n\n***IMPORTANT*** Please visit the Glaze Gallery for examples of available colors. Variation within glazes is part of the handmade and kiln fired nature of this item- click on the name of a glaze to see multiple examples which show the range of variation within each glaze combination. Bowls often have different drip patterns than corresponding mugs. http://www.littleepottery.com/glaze-gallery\n\nfor in stock options visit:\nhttps://www.etsy.com/shop/littleepottery?ref=l2-shopheader-name%C2%A7ion_id§ion_id=7322553\n\nAll of my pieces are dishwasher, microwave, and oven safe.  If you want maximum longevity of glaze shine hand washing is recommended, as dishwasher detergents will etch the surface slowly over time and dull the finish.\n\nThe glazes are my own recipe and contain no lead or other dangerous ingredients. My pieces are fired to 2232 F, and are completely non porous, even in places where there is no glaze. The bottoms of all pieces are bare natural clay, and have a bit of grit to them. It is always okay to sand the bottoms with sandpaper if you prefer a smoother surface. \n\nIf you would like to view other serving and kitchen pieces in my Etsy shop visit my shop section:\nhttps://www.etsy.com/shop/littleepottery?section_id=7322553&ref=shopsection_leftnav_1\n\n\nIf you like my work but do not see the items you want in this Etsy store you can visit my regular website and place a custom order: www.littleepottery.com All custom orders take 5-8 weeks for completion.',
#   'creation_tsz': 1538170640,
#   'ending_tsz': 1548715040,
#   'original_creation_tsz': 1472164865,
#   'last_modified_tsz': 1538170640,
#   'price': '48.00',
#   'currency_code': 'USD',
#   'quantity': 39,
#   'sku': [],
#   'tags': ['little e pottery',
#    'hand thrown',
#    'wheel thrown',
#    'berry bowl',
#    'berry dish',
#    'berry strainer',
#    'strainer',
#    'pottery strainer',
#    'colander',
#    'berry colander',
#    'stoneware colander',
#    'stoneware berry bowl',
#    'pottery berry bowl'],
#   'category_path': ['Housewares'],
#   'category_path_ids': [69150425],
#   'materials': ['stoneware clay', 'hand mixed layered glaze of my own recipe'],
#   'shop_section_id': 7322553,
#   'featured_rank': None,
#   'state_tsz': 1524437074,
#   'url': 'https://www.etsy.com/listing/474686219/large-pottery-berry-bowl-in-your-choice?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 2269,
#   'num_favorers': 185,
#   'shipping_template_id': 26779528534,
#   'processing_min': 20,
#   'processing_max': 30,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1044,
#   'taxonomy_path': ['Home & Living',
#    'Kitchen & Dining',
#    'Dining & Serving',
#    'Bowls'],
#   'used_manufacturer': False},
#  {'listing_id': 549484210,
#   'state': 'active',
#   'user_id': 32933696,
#   'category_id': 69151501,
#   'title': 'Mint Green Earrings, Green Crystal Earrings, Seafoam Earrings Dangle, Bridesmaid Earrings, Mint Green, Alternative Bridesmaid Gift, Seafoam',
#   'description': 'Beautifully bohemian, silver and seafoam green beaded earrings are just luminous. With a single drop of assorted crystals and intricate Tibetian silver beads they are wonderfully light to wear and just the right mix for everyday or your special occasions. Handcrafted with love these are a unique myVardo design.\n\nGreat as a gift for her, a gorgeous choice for alternative bridesmaids and the perfect gift for lovers of green!\n\nThis listing is for 1 x Pair of Green & Silver Crystal Beaded Earrings. myVardo jewellery will arrive well packaged and ready for gifting in a beautiful sari bag. \n\n\nFor more of our silver earrings to go: http://etsy.me/2b4Yqt5\n\nTo find a matching bracelet go to: http://etsy.me/2fhIGDv \n\nYou can check out the whole range of myVardo products at: http://etsy.me/2kgRBHQ\n\n\n* * * * * * *\n\nMEASUREMENTS\n\nLength: 5.3cm (centimetres)\n\n\n* * * * * * *\n\nCUSTOM ORDERS\n\nI am happy to work with you to create a custom piece of jewellery for you. If there is something in my shop that is not quite what you are after or if you have a special piece in mind I may be able make something especially. Send me a message and I will let you know what I can do.\n\nThe myVardo policies section has more information about the custom ordering process but I am always happy to answer your questions personally. \n\nYou can find the myVardo shop policies on this link: http://etsy.me/2bFTCtc',
#   'creation_tsz': 1538170639,
#   'ending_tsz': 1548715039,
#   'original_creation_tsz': 1507440964,
#   'last_modified_tsz': 1538170640,
#   'price': '22.00',
#   'currency_code': 'AUD',
#   'quantity': 2,
#   'sku': [],
#   'tags': ['Mint Green Earrings',
#    'Bohemian Silver',
#    'Green Crystal',
#    'Seafoam Earrings',
#    'Dangle Earrings',
#    'Boho Earrings Mint',
#    'Gypsy Style Jewelry',
#    'myVardo',
#    'Bridesmaid Earrings',
#    'Crystal Earrings',
#    'Mint Green',
#    'Alternative',
#    'Bridesmaid Gifts'],
#   'category_path': ['Jewelry', 'Earrings'],
#   'category_path_ids': [68887482, 69151501],
#   'materials': ['Crystal Beads', 'Tibetian Silver Beads', 'Silver Ear Wires'],
#   'shop_section_id': 17939215,
#   'featured_rank': None,
#   'state_tsz': 1514739480,
#   'url': 'https://www.etsy.com/listing/549484210/mint-green-earrings-green-crystal?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 75,
#   'num_favorers': 13,
#   'shipping_template_id': None,
#   'processing_min': 3,
#   'processing_max': 5,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': ['Boho', 'Avant Garde'],
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1208,
#   'taxonomy_path': ['Jewelry', 'Earrings', 'Dangle & Drop Earrings'],
#   'used_manufacturer': False},
#  {'listing_id': 633420154,
#   'state': 'active',
#   'user_id': 120908734,
#   'category_id': 68925952,
#   'title': 'Thank You Bag, Minimalist, Typography, Printable Wall Art, Printable Art, Instant Download, Digital Download, Poster, 8x10, 16x24',
#   'description': 'INSTANT DIGITAL DOWNLOAD \n\nThis is an instant digital download that will be available to you immediately after purchase. \n\nHOW TO DOWNLOAD\nYou will be emailed a download link immediately after checkout. You will also be able to access these files at all times through Etsy&#39;s purchases page.\n\nYOUR FILES\nYou will receive 2 high resolution JPG file (300 dpi) in both 4:5 ratio and 4:6 ratio.\n4:5 ratio file is suitable for print in any of the following sizes: 4x5, 8x10, 12x15, 16x20, 20x25, 24x30.\n4:6 ratio file is suitable for print in any of the following sizes: 4x6, 8x12, 12x18, 16x24 20x30, 24x36.\n\nWHERE TO PRINT\nPlease be aware that this is NOT a physical printed poster. Rather, your files can be printed on your home computer or through various companies including Staples, Walgreens, CVS, Shutterfly, and Snapfish.\n\nCOLOR ACCURACY\nColors may print differently than they appear on your screen depending on your monitor and the quality of the printing source you choose.\n\nTERMS OF USE\nFiles can be printed in unlimited quantities for your personal use only but cannot be used for commercial purposes and cannot be resold or redistributed.\n\nQUESTIONS\nPlease reach out via message if you have any questions. I am very happy to help!',
#   'creation_tsz': 1538170639,
#   'ending_tsz': 1548715039,
#   'original_creation_tsz': 1538170639,
#   'last_modified_tsz': 1538170639,
#   'price': '3.00',
#   'currency_code': 'USD',
#   'quantity': 20,
#   'sku': [],
#   'tags': ['wall art',
#    'digital download',
#    'quote poster',
#    'printable poster',
#    'instant download',
#    '8x10',
#    '16x24',
#    'typography',
#    'minimalist poster',
#    'typography poster',
#    'thank you poster',
#    'thank you typography',
#    'thank you art'],
#   'category_path': ['Art', 'Print', 'Digital'],
#   'category_path_ids': [68887312, 68892154, 68925952],
#   'materials': [],
#   'shop_section_id': 24398854,
#   'featured_rank': None,
#   'state_tsz': 1538170639,
#   'url': 'https://www.etsy.com/listing/633420154/thank-you-bag-minimalist-typography?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 0,
#   'num_favorers': 0,
#   'shipping_template_id': None,
#   'processing_min': None,
#   'processing_max': None,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': True,
#   'file_data': '1 ZIP',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 2078,
#   'taxonomy_path': ['Art & Collectibles', 'Prints', 'Digital Prints'],
#   'used_manufacturer': False},
#  {'listing_id': 555311231,
#   'state': 'active',
#   'user_id': 21403414,
#   'category_id': 69154651,
#   'title': 'THE SEVILLE 18x18 Violet and Pink Denim Square Pillow Cover',
#   'description': 'THE SEVILLE Violet and Pink Denim Square Pillow Cover\n\nFRONT: This pillow is handcrafted from denim \nBACK: Natural cream denim \nZIPPER: Bottom close, brass zipper\nSIZE: 18x18\n\n(INSERT NOT INCLUDED) \nTo get your pillow to look its best, I suggest a feather insert that is 2 inches larger than cover. (20x20 insert, shop link below) \nhttps://www.etsy.com/TheIvoryGull/listing/567777510/pillow-inserts?utm_source=Copy&utm_medium=ListingManager&utm_campaign=Share&utm_term=so.lmsm&share_time=1530898972678\n\nCARE: \nHand Wash Separately Cold, No Bleach, Line Dry, Cool Iron',
#   'creation_tsz': 1538170632,
#   'ending_tsz': 1548715032,
#   'original_creation_tsz': 1504293300,
#   'last_modified_tsz': 1538170848,
#   'price': '45.00',
#   'currency_code': 'USD',
#   'quantity': 2,
#   'sku': [],
#   'tags': ['Boho Pillow',
#    'Tribal Pillow',
#    'Fall',
#    'Theivorygull',
#    'the ivory gull',
#    'home decor',
#    'pillow covers',
#    'gold zipper',
#    'brass zipper',
#    'windowpane',
#    'window pane',
#    'pink pillow',
#    'denim pillow'],
# ...
#   'creation_tsz': 1538170627,
#   'ending_tsz': 1548715027,
#   'original_creation_tsz': 1525695457,
#   'last_modified_tsz': 1538170628,
#   'price': '40.00',
#   'currency_code': 'CAD',
#   'quantity': 1,
#   'sku': [],
#   'tags': ['meditation bracelet',
#    'Alabaster Bracelet',
#    'handmade bracelets',
#    'unisex men Bracelet',
#    'energy Bracelet',
#    'white bracelets',
#    'yoga mala bracelets',
#    'Buddhist jewelry',
#    'most popular item',
#    'best selling item',
#    'lucky reiki bracelet',
#    'black red bracelet',
#    '925 silver bracelet'],
#   'category_path': ['Jewelry', 'Bracelet'],
#   'category_path_ids': [68887482, 68888548],
#   'materials': ['Onyx', 'Silver'],
#   'shop_section_id': 18464127,
#   'featured_rank': None,
#   'state_tsz': 1536415235,
#   'url': 'https://www.etsy.com/listing/612683343/6mm-white-alabaster-onyx-jade-gemstones?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 7,
#   'num_favorers': 0,
#   'shipping_template_id': 47529711057,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': True,
#   'taxonomy_id': 1193,
#   'taxonomy_path': ['Jewelry', 'Bracelets'],
#   'used_manufacturer': False},
#  {'listing_id': 621341897,
#   'state': 'active',
#   'user_id': 79483709,
#   'category_id': 69150433,
#   'title': 'Astronaut Themed Party Banner, Moon Banner Printable, Outer Space Birthday Banner, Rocketship Boy Banner, Love You To The Moon Banner, DIY',
#   'description': '✦ INSTANT DOWNLOAD ✦\nThere&#39;s no waiting! My best selling rocketship, moon and astronaut artwork ready to be cutout for your out of this world party. Each banner flag is 5&quot; x 7.5&quot; each, and prints two per page.\n\n✦ WHAT YOU&#39;LL NEED TO ASSEMBLE YOUR BANNER ✦\n▶ After checkout, simply download the files & follow the instructions\n▶ I highly recommend card stock, matte or glossy photo paper for the highest quality printing\n▶ Twine or string\n▶ Scissors\n▶ Hole punch (optional)\n\n✦ MATCHING PARTY DECOR & BIRTHDAY SHIRTS✦\nhttps://www.etsy.com/shop/MochaMommyDesigns?section_id=23134209\n\n✦ SHOP HOMEPAGE ✦\nwww.etsy.com/shop/MochaMommyDesigns\n\n=================================\n10% OFF COUPON \nFollow the link to join my VIP Club\nfor an instant coupon via email!\nwww.mochamommy.com/signup \n=================================\n\n✦ GOOD INFO TO KNOW ✦\n▶ All images are high quality. \n▶ Files are for personal use only.\n▶ No physical products will be sent. Instant download only. \n▶ Please do not reproduce or resell my homemade prints.\n▶ You will need Adobe Reader to access your instant download files. If you don&#39;t have it on your computer already, that&#39;s no problem. I have included instructions on how to download it for free in the files you will receive. \n▶ I want you to be happy with your printables! Please let me know if you&#39;re not. \n\n✦ STILL HAVE QUESTIONS? ✦\nNo problem! Contact me anytime by clicking the &quot;Ask a question&quot; button by the price above, and I&#39;ll get back to you as soon as possible.',
#   'creation_tsz': 1538170625,
#   'ending_tsz': 1548715025,
#   'original_creation_tsz': 1529108484,
#   'last_modified_tsz': 1538170625,
#   'price': '6.00',
#   'currency_code': 'USD',
#   'quantity': 993,
#   'sku': [],
#   'tags': ['Party Supplies',
#    'Party Decor',
#    'Kids Moon',
#    'Birthday Party',
#    'Solar System',
#    'Birthday Banner',
#    'Outer Space Themed',
#    'Astronaut Theme',
#    'Boy Party',
#    'Printable Party',
#    'Party Banner',
#    'Rocketship',
#    'Turquoise'],
#   'category_path': ['Supplies'],
#   'category_path_ids': [69150433],
#   'materials': [],
#   'shop_section_id': 23134209,
#   'featured_rank': None,
#   'state_tsz': 1529413904,
#   'url': 'https://www.etsy.com/listing/621341897/astronaut-themed-party-banner-moon?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 100,
#   'num_favorers': 16,
#   'shipping_template_id': None,
#   'processing_min': None,
#   'processing_max': None,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': True,
#   'file_data': '2 PDF',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 6612,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Party & Gifting',
#    'Party Supplies',
#    'Party Favors'],
#   'used_manufacturer': False},
#  {'listing_id': 600976712,
#   'state': 'active',
#   'user_id': 68509368,
#   'category_id': 69150467,
#   'title': 'Reusable sandwich bag // reusable snack bag // waterproof reusable sandwich bag // waterproof reusable bag //zipped sandwich bag',
#   'description': 'ONE sandwich bag ONE snack bag and ONE mini snack bag. Those waterproof reusable bags are ideal for veggies, cookies, crackers, and fruits. \n\nFabric, zipper, label 100% made in Québec\n\nFood grade, the fabrics are BPA-free, lead-free, PVC-free, and any other product that we absolutely do not want to find in our lunch box!\n\nTop closes with zipper\nTo clean you can turn inside out to shake out or wipe with a damp cloth. \nMachine wash hot water, tumble dry. \n\nSandwich bag measures 7,25&quot; x 6,75&quot;(18 cm X 17 cm)\nSnack bag measures 7,25&quot; x 4,75&quot; (18 cm x 12 cm) \nMini snack bag measures  5,25&quot;x 4,75&quot;(14 X 12cm)\n\nPlease note that the pattern placement may vary.',
#   'creation_tsz': 1538170624,
#   'ending_tsz': 1548715024,
#   'original_creation_tsz': 1526505327,
#   'last_modified_tsz': 1538170624,
#   'price': '24.00',
#   'currency_code': 'CAD',
#   'quantity': 7,
#   'sku': [],
#   'tags': ['ecofriendly',
#    'food safe',
#    'green lunch solution',
#    'adult',
#    'ziplock',
#    'panda roux',
#    'geometrical',
#    'for teens',
#    'Reusable bag',
#    'sandwich bag',
#    'snack bag',
#    'waterproof bag',
#    'demain demain'],
#   'category_path': ['Accessories'],
#   'category_path_ids': [69150467],
#   'materials': ['PUL Fabric', 'YKK zipper', 'Woven label'],
#   'shop_section_id': 22773568,
#   'featured_rank': None,
#   'state_tsz': 1533902372,
#   'url': 'https://www.etsy.com/listing/600976712/reusable-sandwich-bag-reusable-snack-bag?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 155,
#   'num_favorers': 28,
#   'shipping_template_id': 24150645241,
#   'processing_min': 1,
#   'processing_max': 3,
#   'who_made': 'i_did',
#   'is_supply': 'false',
#   'when_made': 'made_to_order',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': False,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 1,
#   'taxonomy_path': ['Accessories'],
#   'used_manufacturer': False},
#  {'listing_id': 233418929,
#   'state': 'active',
#   'user_id': 40316623,
#   'category_id': 69150433,
#   'title': '12&quot; x 15&quot; / 15pk - Siser EasyWeed HTV - Heat Transfer Vinyl',
#   'description': 'This listing is for 15 Sheets (12&quot; x 15&quot;) Siser EasyWeed HTV- You Pick The Color!! \n\nLeave a note with your color choices in the Note from Buyer section when checking out!   \n  \n15” sheets approximate width is 14.75“\n\nNEW COLORS: Orange Soda and Wicked Purple\n\nSave by ordering multi packs (seen on our web store: onesourcecraftstore.com) \n2pk       $2.60 ea sheet     (save 20%)\n5pk       $2.25 ea sheet     (save 31%)\n10pk     $2.20 ea sheet     (save 32%)\n15pk     $2.15 ea sheet      (save 34%)\n20pk    $2.14 ea sheet      (save 33%)\n25pk    $2.13  ea sheet     \n50pk    $2.12 ea sheet      \n75pk     $2.10 ea sheet     \n100pk   $2.09 ea sheet    \n150pk   $2.08 ea sheet\n\n***COMBINE SHIPPING DISCOUNT - $.99/EA FOR ADDITIONAL ITEM***\n____________________________________________________________________________________\n\nFLUORESCENT EASYWEED HTV CANNOT BE ORDERED WITH THE REGULAR EASYWEED HTV COLORS. PLEASE LOOK FOR A SEPARATE LISTING FOR THE FLUORESCENT EASYWEED HTV.\n\nWhat sets EasyWeed apart? For more info go to www.siserna.com/easyweed\n\nThe EasyWeed advantage! Lower temperature, HOT or COLD peel, no lifting, durability wash after wash, and lower pressure. It’s thinner than the competitors’ material and offers a one-step application that’s great for multiple layers. Comes on a pressure-sensitive carrier.\n\nEasyWeed will adhere to 100% Cotton, 100% Uncoated Polyester, Cotton/Polyester Blends. \n\nCut your image in reverse/mirror. Easily applies with a heat press or home iron on a cotton setting!\n\nThis item does come with instructions on cutting and application!\n\nOne Source Supply is a  Authorized Distributor of all products we sell.\nThis means we purchase direct from the manufacturer.\n              ****Products are Always Fresh**** \n\nIf you have any questions, call our customer service line at: 810-635-8844\n\nWe ship items Monday - Friday Eastern Time. No Saturday, Sunday or Holiday shipping. \nOrders placed before 2:00 pm est. shipped same day.\n\nVisit our Facebook Page at: One Source Supply',
#   'creation_tsz': 1538170624,
#   'ending_tsz': 1548715024,
#   'original_creation_tsz': 1431635556,
#   'last_modified_tsz': 1538170624,
#   'price': '32.25',
#   'currency_code': 'USD',
#   'quantity': 406,
#   'sku': [],
#   'tags': ['iron on vinyl',
#    'tshirt vinyl',
#    'cricut vinyl',
#    'iron on patch',
#    'vinyl heat transfer',
#    'silhouette vinyl',
#    'craft cutter',
#    'pazzle vinyl',
#    'craft vinyl',
#    'heat transfer vinyl',
#    'vinyl',
#    'siser easyweed',
#    'easyweed'],
#   'category_path': ['Supplies'],
#   'category_path_ids': [69150433],
#   'materials': ['Siser EasyWeed', 'Heat Transfer Vinyl', 'Vinyl'],
#   'shop_section_id': 16278562,
#   'featured_rank': None,
#   'state_tsz': 1533821469,
#   'url': 'https://www.etsy.com/listing/233418929/12-x-15-15pk-siser-easyweed-htv-heat?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 4399,
#   'num_favorers': 107,
#   'shipping_template_id': None,
#   'processing_min': 1,
#   'processing_max': 1,
#   'who_made': 'someone_else',
#   'is_supply': 'true',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': 'oz',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'in',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': False,
#   'is_customizable': False,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 562,
#   'taxonomy_path': ['Craft Supplies & Tools'],
#   'used_manufacturer': False},
#  {'listing_id': 76047324,
#   'state': 'active',
#   'user_id': 14972985,
#   'category_id': 69150433,
#   'title': '100 pcs Swarovski Elements - Swarovski Crystal Beads 5328 4mm Xillion Beads - CHRYSOLITE',
#   'description': 'The brilliant XILION CUT\r\nSince the launch of the XILION Chaton & Rose, XILION has stood for the utmost brilliance, intense sparkle and fascinating light effects. The sophisticated interplay of large and small facets that is the hallmark of the XILION cut is developed using state-of-the-art technology, and adapted to the specific product group: the result is optimal refraction, which intensifies the light and makes the crystal irresistibly attractive.\r\n\r\nFollowing the successful introduction of the XILION family, a further key product that features the XILION cut will now debut: XILION Bead (article 5328).\r\n\r\nFascinating benefits\r\nJust as the one-of-a-kind brilliance and intense luminosity of the new XILION Bead ensure clear differentiation possibilities. The bead’s especially round equator provides increased wearing comfort. The new XILION Bead also benefits customers in the following ways:\r\n\r\n\r\n\r\nComplex faceting and geometric perfection: patented XILION cut\r\nAttractive form through increased number of facets\r\nCan be combined with previous bead (article 5301)\r\n\r\n\r\n\r\nPolished, crystal-clear hole creates increased brilliance\r\nOnly SWAROVSKI ELEMENTS offers rounded hole edges that protect thread for long-lasting designs\r\n\r\n\r\nPatented cut\r\nFrom small to large, absolutely precision-cut facets are arranged to optimally draw in and refract light. The XILION cut is patentprotected by Swarovski.\r\n\r\nOptimal reflection\r\nBoth the outstanding light reflection and the optimal light distribution that characterizes the XILION cut have been confirmed in studies performed by the Swarovski light lab in collaboration with the renowned Fraunhofer Institute (IOF).\r\n\r\n\r\nSwarovski Crystal\r\nThe name Swarovski has been inextricably linked to precision cut crystal and fashion for more than 113 years. The founder Daniel Swarovski I, born in Northern Bohemia in 1862, the centre of a flourishing crystal and costume jewellery industry, was fascinated with crystal from his earliest years. As a young man he showed an aptitude for invention and entrepreneurship that was to form the basis of what today is a family company employing 20,000 people and with a presence in more than 120 countries.\r\nAustrian Swarovski is the Finest High Quality Crystals made today. It contain a minimum of 32% lead Making The Crystal so Pure. Crystals are faceted with high tremendous Precision, Creating Stunning Prism in any light source area.\r\nSo if you are looking for some Crystals. Please insist on Swarovski Crystals.',
#   'creation_tsz': 1538170624,
#   'ending_tsz': 1548715024,
#   'original_creation_tsz': 1308159535,
#   'last_modified_tsz': 1538170624,
#   'price': '4.99',
#   'currency_code': 'USD',
#   'quantity': 14,
#   'sku': [],
#   'tags': ['Swarovski',
#    'beads',
#    '4mm',
#    '5328',
#    'Xillion',
#    'crystal',
#    'elements',
#    'WITHOUT COATING',
#    'NORMAL'],
#   'category_path': ['Supplies'],
#   'category_path_ids': [69150433],
#   'materials': ['crystal', 'Swarovski Crystal', 'Man made Crystal'],
#   'shop_section_id': 8144784,
#   'featured_rank': None,
#   'state_tsz': 1519665636,
#   'url': 'https://www.etsy.com/listing/76047324/100-pcs-swarovski-elements-swarovski?utm_source=haidysedky&utm_medium=api&utm_campaign=api',
#   'views': 118,
#   'num_favorers': 18,
#   'shipping_template_id': 17523453,
#   'processing_min': 1,
#   'processing_max': 2,
#   'who_made': 'someone_else',
#   'is_supply': 'true',
#   'when_made': '2010_2018',
#   'item_weight': None,
#   'item_weight_unit': 'g',
#   'item_length': None,
#   'item_width': None,
#   'item_height': None,
#   'item_dimensions_unit': 'mm',
#   'is_private': False,
#   'recipient': None,
#   'occasion': None,
#   'style': None,
#   'non_taxable': True,
#   'is_customizable': True,
#   'is_digital': False,
#   'file_data': '',
#   'should_auto_renew': True,
#   'language': 'en-US',
#   'has_variations': False,
#   'taxonomy_id': 6238,
#   'taxonomy_path': ['Craft Supplies & Tools',
#    'Beads, Gems & Cabochons',
#    'Beads'],
#   'used_manufacturer': False}]
